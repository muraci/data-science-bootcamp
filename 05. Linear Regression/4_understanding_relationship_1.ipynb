# %% [markdown]
# - _Ev Fiyatları verilerini Kaggle'dan indirin._
# - _Ev fiyatları modelinizi tekrar çalıştırın ve sonuçları yorumlayın. Hangi özellikler istatistiksel olarak anlamlı ve hangileri değildir?_
# - _Şimdi, anlamsız özellikleri modelinizden hariç tutun. Bir şey değişti mi?_
# - _Ev fiyatları ile olan ilişkilerini belirleyerek istatistiksel olarak anlamlı katsayıları yorumlayın. Ev fiyatları üzerinde hangi özellikler daha belirgin bir etkiye sahiptir?_
# - _Sonuçlar size mantıklı geliyor mu? Değilse, potansiyel nedenleri açıklamaya çalışın._

# %% [markdown]
# > Önceki ödevin üzerinden devam edilmiştir.

# %%
Y = dfc['SalePrice']
X = dfc[['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
       'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
       'YearRemodAdd', 'KitchenQual_Ex', 'Foundation_PConc', 'Fireplaces',
       'ExterQual_Gd', 'ExterQual_Ex', 'HeatingQC_Ex', 'Neighborhood_NridgHt']]

# %%
randomNum = np.random.normal(np.mean(Y), np.std(Y), len(Y))

plt.figure(figsize=(20,4))
plt.subplot(1, 3, 1)
sns.scatterplot(x=randomNum, y=Y)
plt.subplot(1, 3, 2)
sns.distplot(Y)
plt.subplot(1, 3, 3)
sns.regplot(np.sort(randomNum), np.sort(Y))
plt.show()

# %%
model = LinearRegression().fit(X, Y)

# %%
X = sm.add_constant(X)
results = sm.OLS(Y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     351.1
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):               0.00
# Time:                        01:30:43   Log-Likelihood:                -17337.
# No. Observations:                1459   AIC:                         3.471e+04
# Df Residuals:                    1441   BIC:                         3.481e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
Y2 = dfc['SalePrice']
X2 = dfc[['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'YearBuilt', 'YearRemodAdd']]

# %%
model = LinearRegression().fit(X2, Y2)

# %%
X2 = sm.add_constant(X2)
results = sm.OLS(Y2, X2).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     698.4
# Date:                Thu, 02 Apr 2020   Prob (F-statistic):               0.00
# Time:                        01:31:20   Log-Likelihood:                -17456.
# No. Observations:                1459   AIC:                         3.493e+04
# Df Residuals:                    1451   BIC:                         3.497e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# - Dummy değerlerimiz multicollinearity'e sebep olmaktadır.
# - Özelliklerin kaldırılmasıyla R-sq. değerimizde azalma gözlemlendi. Modelin anlamsızlaştığını gösterir, ama büyük bir düşüş değildir.
# - Kategorik değerleri teke indirmediğimizden dolayı artıklar oldukça yüksek görünüyor.
# - p-değeri yüksek olan özelliklerin katsayılarında negatif sayılar gözlemlenmektedir.
# - Veri setine oldukça fazla ilişkili sütun bulunduğundan dolayı, daha anlamlı sonuç alabilmek için PCA uygulanmalıdır.
